# %% [markdown]
# <a href="https://colab.research.google.com/github/mdparvejkhanhstu/MyPortfolio/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import warnings; warnings.filterwarnings('ignore')

print(f"NumPy  {np.__version__}\nPandas {pd.__version__}")
# Out:
# NumPy  2.0.2
# Pandas 2.2.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path ='/content/drive/MyDrive/Colab Notebooks/Heart_Disease_Prediction.csv'
columns = ['Age', 'Sex', 'Chest pain type', 'BP',
           'Cholesterol', 'FBS over 120', 'EKG result', 'Max HR', 'Excercise angina','ST depression','Slope of ST','Number of vessels fluro','Thallium','Heart Disease']

# %%
df = pd.read_csv(file_path, names=columns)   # raw CSV has no header
print('Loaded:', df.shape)
df.head()
# Out:
# Loaded: (271, 14)
#    Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120   EKG result  \
# 0  Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results
# 1   70    1                4  130          322             0            2
# 2   67    0                3  115          564             0            2
# 3   57    1                2  124          261             0            0
# 4   64    1                4  128          263             0            0
#
#    Max HR Excercise angina  ST depression  Slope of ST  \
# 0  Max HR  Exercise angina  ST depression  Slope of ST
# 1     109                0            2.4            2
# 2     160                0            1.6            2
# 3     141                0            0.3            1
# 4     105                1            0.2            2
#
#    Number of vessels fluro  Thallium  Heart Disease
# 0  Number of vessels fluro  Thallium  Heart Disease
# 1                        3         3       Presence
# ...

# %%
df.describe()
# Out:
#         Age  Sex Chest pain type   BP Cholesterol FBS over 120 EKG result  \
# count   271  271             271  271         271          271        271
# unique   42    3               5   48         145            3          4
# top      54    1               4  120         234            0          2
# freq     16  183             129   34           6          230        137
#
#        Max HR Excercise angina ST depression Slope of ST  \
# count     271              271           271         271
# unique     91                3            40           4
# top       162                0             0           1
# freq       10              181            85         130
#
#        Number of vessels fluro Thallium Heart Disease
# count                      271      271           271
# unique                       5        4             3
# top                          0        3       Absence
# freq                       160      152           150
